# %% [markdown]
# #Hive
# Hive is a thrift server engine built on top of Hadoop that enables querying and managing large datasets stored in a distributed environment. Stores in Mapreduced format.

# %% [markdown]
# how hadoop system converts java code to query languages?
#
# Map reduce work on Java, instead of writing long java code we can write hive queries in single line and hive will do further processing.
#
# Utility is nothing but extracting complex query from the user.

# %% [markdown]
# Why Metadata is stored in databases?
# 1. In HDFS retrieve and update and edits are difficult.
# 2. Use Metadata for fast retieval of data in databases(Low Latency).

# %%
execute
send to compiler
store the metadat
retieve from metadata
send info to friver
execution
deletion of culumn

# %%
hive components
